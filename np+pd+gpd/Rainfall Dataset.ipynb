# %% [markdown]
# # Rainfall Dataset
# Create:
# ```python
# rainfall = {
#     "District": [...],
#     "Rainfall": [...]
# }
# ```
# ## Tasks:
#
# - Convert to DataFrame
# - Find mean
# - Find max
# - Sort by rainfall
# - Plot bar chart
#
# ## Concepts:
#
# - NumPy
# - Pandas
# - Matplotlib

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
pip install openpyxl
# Out:
# ...
#    ---------------------------------------- 0.0/250.9 kB ? eta -:--:--
#    - -------------------------------------- 10.2/250.9 kB ? eta -:--:--
#    ------ -------------------------------- 41.0/250.9 kB 487.6 kB/s eta 0:00:01
#    -------------------------------- ------- 204.8/250.9 kB 1.8 MB/s eta 0:00:01
#    ---------------------------------------- 250.9/250.9 kB 1.7 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: C:\Users\aksha\AppData\Local\Programs\Python\Python311\python.exe -m pip install --upgrade pip

# %%
url=r"C:\Users\aksha\Projects\py-library_pract\np+pd+gpd\data\rain.xlsx"
df=pd.read_excel(url, engine="openpyxl")

# %%
df.head()
# Out:
#          District  Rainfall
# 0       Kasaragod    3607.8
# 1  Pathanamthitta    2318.9
# 2       Kozhikode    2879.4
# 3         Wayanad    2682.5
# 4          Kollam    1763.2

# %%
df.plot( x="District", y="Rainfall", kind="line", figsize=(10,5) )
# Out:
# <Axes: xlabel='District'>

# %%
df.plot.bar(x="District", y="Rainfall", color="blue", figsize=(10,5))

plt.title("Kerala District Rainfall")
plt.ylabel("Rainfall")
plt.show()

# %%
df_mean=df["Rainfall"].mean()
df_mean
# Out:
# np.float64(2607.3733333333334)

# %%
df_max=df["Rainfall"].max()
df_max
# Out:
# np.float64(3607.8)

# %%
df_sort = df.sort_values("Rainfall")
df_sort
# Out:
#               District  Rainfall
# 9   Thiruvananthapuram    1629.3
# 4               Kollam    1763.2
# 7             Palakkad    2125.9
# 8           Malappuram    2138.2
# 10           Alappuzha    2216.2
# 1       Pathanamthitta    2318.9
# 13            Thrissur    2606.4
# 6             Kottayam    2648.2
# 3              Wayanad    2682.5
# 5               Idukki    2737.2
# 2            Kozhikode    2879.4
# 11                Mahe    3150.4
# 12           Ernakulam    3179.9
# 14              Kannur    3427.1
# 0            Kasaragod    3607.8

# %%
df_sort = df["Rainfall"].sort_values(ascending=False) #high to low
df_sort
# Out:
# 0     3607.8
# 14    3427.1
# 12    3179.9
# 11    3150.4
# 2     2879.4
# 5     2737.2
# 3     2682.5
# 6     2648.2
# 13    2606.4
# 1     2318.9
# 10    2216.2
# 8     2138.2
# 7     2125.9
# 4     1763.2
# 9     1629.3
# Name: Rainfall, dtype: float64
